# %%
import os
import sys
from agents import Agent, Runner, function_tool, ItemHelpers

@function_tool
def get_weather(city: str) -> str:
    """
    Get weather by city
    """
    return "30 degrees"

agent = Agent(
    name="Assistant Agent",
    instructions="You are a helpful assistant. Use tools when needed to answer the user's question.",
    tools=[get_weather]
)

stream = Runner.run_streamed(agent, "안녕 잘 지내니? 서울 날씨는 어때? 지금 서울 여행 할만해?? 서울 여행 코스 좀 계획해줘")

message = ""
args = ""

async for event in stream.stream_events():
    if event.type == "raw_response_event":
        event_type = event.data.type

        if event_type == "response.output_text.delta":
            print(event.data.delta, end='', flush=True)
            message += event.data.delta
        elif event_type == "response.function_call_arguments.delta":
            print(event.data.delta, end='', flush=True)
            args += event.data.delta
        elif event_type == "response.output_text.done":
            print()
        elif event_type == "response.function_call_arguments.done":
            print()
        elif event_type == "response.completed":
            message = ""
            args = ""
# Out:
# {"city":"Seoul"}
# 안녕하세요! 저는 항상 잘 지내고 있어요. 질문해 주셔서 감사합니다.
#
# 현재 서울의 날씨는 약 30도 정도로, 더운 여름 날씨입니다. 햇볕이 강하고 더운 편이니, 여행하실 때 모자나 선글라스, 물 등을 꼭 챙기시는 것이 좋아요. 실내·야외 활동을 적절히 조합한다면 충분히 즐거운 여행이 될 거예요!
#
# 간단하게 1일 기준 서울 여행 코스를 제안드릴게요.
#
# 서울 1일 여행 코스 추천
#
# 1. 오전
# - 경복궁: 전통 궁궐을 체험하고, 한복 대여해 사진도 찍어보세요.
# - 광화문광장: 경복궁 앞에서 도보로 이동, 세종대왕 동상 등 볼거리 감상
#
# 2. 점심
# - 인사동: 전통 음식점과 현대적 카페, 기념품 가게가 많아서 맛집 탐방 및 쇼핑
#
# 3. 오후
# - 북촌한옥마을: 전통 한옥 골목 산책, 한옥카페에서 휴식
# - 청계천: 시원한 물길 따라 산책하며 더위 식히기
#
# 4. 저녁
# - 남산타워(서울N타워): 야경 감상, 케이블카 타기
# - 명동/동대문: 쇼핑과 스트리트푸드, 야경 산책
#
# 조금 더 길게 여행 일정이나, 테마별(맛집, 문화, 자연 등) 코스가 필요하시면 추가로 알려주세요!
